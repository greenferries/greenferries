# %%
import os, sys, re, frontmatter
import sqlite3
import pandas as pd

# %%
REPO_ROOT = os.path.join(os.path.abspath(''), "..")
sys.path.append(REPO_ROOT)
    
def get_df(dirname):
    dirpath = os.path.join(REPO_ROOT, "www/11ty_input", dirname)
    items = []
    for filename in os.listdir(dirpath):
        # print(f"Processing {filename}")
        match_data = re.match(r".*\.md", filename)
        if not match_data:
            continue
        item = frontmatter.load(os.path.join(dirpath, filename)).metadata
        items.append(item)
    return pd.DataFrame(items).drop(columns=["tags", "layout"])

# %%
df_routes = get_df("routes") \
  .set_index("slug") \
  .rename(columns={"cityA": "city_a_slug", "cityB": "city_b_slug", "distanceKm": "distance_km", "distanceNms": "distance_nms"})
df_routes
# Out:
#                                      city_a_slug            city_b_slug  \
# slug
# chios-gr-karlovassi-gr           gr-chios-259973   gr-karlovassi-256492
# guernesey-gg-saint-malo-fr  gg-guernesey-3042287  fr-saint-malo-2978640
# savona-it-bastia-fr            it-savona-3167022      fr-bastia-3034640
# oinousses-gr-le-piree-gr     gr-oinousses-256329     gr-le-piree-255274
# genes-it-barcelone-es           it-genes-3176219   es-barcelone-3128760
# ...                                          ...                    ...
# arrecife-es-cadiz-es         es-arrecife-2521570       es-cadiz-2520600
# barcelone-es-ibiza-es       es-barcelone-3128760       es-ibiza-2516479
# heraklion-gr-le-piree-gr     gr-heraklion-261745     gr-le-piree-255274
# kaskinen-fi-harnosand-se      fi-kaskinen-653758   se-harnosand-2707684
# barcelone-es-formentera-es  es-barcelone-3128760  es-formentera-2511381
#
#                             distance_km  distance_nms
# slug
# chios-gr-karlovassi-gr               81     43.851103
# guernesey-gg-saint-malo-fr           98     53.114364
# savona-it-bastia-fr                 192    103.776676
# oinousses-gr-le-piree-gr            234    126.412493
# genes-it-barcelone-es               646    349.306620
# ...                                 ...           ...
# arrecife-es-cadiz-es               1081    583.837047
# barcelone-es-ibiza-es               282    152.749601
# heraklion-gr-le-piree-gr            320    172.924542
# kaskinen-fi-harnosand-se            171     92.357407
# barcelone-es-formentera-es          305    164.736180
#
# [207 rows x 4 columns]

# %%
df_companies = get_df("companies") \
    .set_index("slug") \
    .rename(columns={"officialUrl": "official_url", "wikipediaUrl": "wikipedia_url", "outOfScope": "out_of_scope"})
df_companies["out_of_scope"] = df_companies.out_of_scope.apply(lambda x: x == True)
df_companies["out_of_scope"] = df_companies.out_of_scope.astype(bool)
# reorder columns
df_companies = df_companies[["name", "country", "out_of_scope", "imo", "logo", "official_url", "wikipedia_url"]]
df_companies.dtypes
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 df_companies = get_df("companies") \
#       2     .set_index("slug") \
#       3     .rename(columns={"officialUrl": "official_url", "wikipediaUrl": "wikipedia_url", "outOfScope": "out_of_scope"})
#       4 df_companies["out_of_scope"] = df_companies.out_of_scope.apply(lambda x: x == True)
#       5 df_companies["out_of_scope"] = df_companies.out_of_scope.astype(bool)
#
# Cell In[45], line 7, in get_df(dirname)
#       5 dirpath = os.path.join(REPO_ROOT, "www/11ty_input", dirname)
#       6 items = []
# ----> 7 for filename in os.listdir(dirpath):
#       8     # print(f"Processing {filename}")
#       9     match_data = re.match(r".*\.md", filename)
#      10     if not match_data:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/adipasquale/dev/greenferries/notebooks/../www/11ty_input/companies'

# %%
df_cities = get_df("cities") \
    .set_index("slug") \
    .rename(columns = {"geonamesId": "geonames_id", "targetAirportCode": "target_airport_code"})

df_cities = df_cities[["name", "country", "geonames_id", "latitude", "longitude", "target_airport_code"]]
df_cities
# Out:
#                                    name country  geonames_id  latitude  \
# slug
# dk-frederikshavn-2621927  Frederikshavn      DK      2621927  57.44073
# se-trelleborg-2667402        Trelleborg      SE      2667402  55.37514
# dk-grena-2621230                  Grenå      DK      2621230  56.41578
# ee-paldiski-589663             Paldiski      EE       589663  59.35667
# fr-le-havre-3003796            Le Havre      FR      3003796  49.48510
# ...                                 ...     ...          ...       ...
# gb-lerwick-2644605              Lerwick      GB      2644605  60.15339
# se-grisslehamn-2710606      Grisslehamn      SE      2710606  60.10048
# ax-lumparland-647455         Lumparland      AX       647455  60.11695
# gb-brodick-2654604              Brodick      GB      2654604  55.57539
# gr-karlovassi-256492         Karlovassi      GR       256492  37.79209
#
#                           longitude target_airport_code
# slug
# dk-frederikshavn-2621927   10.53661                 CNL
# se-trelleborg-2667402      13.15691                 MMX
# dk-grena-2621230           10.87825                 AAR
# ee-paldiski-589663         24.05306                 TLL
# fr-le-havre-3003796         0.11440                 LEH
# ...                             ...                 ...
# gb-lerwick-2644605         -1.14427                 LSI
# se-grisslehamn-2710606     18.80819                 ARN
# ax-lumparland-647455       20.25819                 NaN
# gb-brodick-2654604         -5.14717                 PIK
# gr-karlovassi-256492       26.70490                 SMI
#
# [187 rows x 6 columns]

# %%
df_ships = get_df("ships") \
    .set_index("imo") \
    .rename(columns={"outOfScope": "out_of_scope", "wikipediaUrl": "wikipedia_url", "unknownRoutes": "unknown_routes", "capacityPax": "capacity_pax", "company": "company_slug"})
df_ships["out_of_scope"] = df_ships.out_of_scope.apply(lambda x: x == True)
df_ships["out_of_scope"] = df_ships.out_of_scope.astype(bool)
df_ships["unknown_routes"] = df_ships.unknown_routes.apply(lambda x: x == True)
df_ships["unknown_routes"] = df_ships.unknown_routes.astype(bool)
df_ships_routes = df_ships["routes"].explode().dropna().reset_index().rename(columns={"routes": "route_slug"})
df_ships_routes
df_ships = df_ships[["name", "slug", "company_slug", "out_of_scope", "photo", "wikipedia_url", "unknown_routes", "capacity_pax"]]
df_ships
# Out:
#                        name                        slug  \
# imo
# 9332559    MS Stena Horizon    ms-stena-horizon-9332559
# 9783576       Mein Schiff 2       mein-schiff-2-9783576
# 9215490  Caribbean Princess  caribbean-princess-9215490
# 9364722             MS Star             ms-star-9364722
# 9813072      ROALD AMUNDSEN      roald-amundsen-9813072
# ...                     ...                         ...
# 7361324        MS Moby Otta        ms-moby-otta-7361324
# 9479864     Costa Fascinosa     costa-fascinosa-9479864
# 9767091    CARNIVAL HORIZON    carnival-horizon-9767091
# 9221346  HSC Volcan de Teno  hsc-volcan-de-teno-9221346
# 9501590       HSC Express 1           express-1-9501590
#
#                     company_slug  out_of_scope  \
# imo
# 9332559            stena-line-se         False
# 9783576           tui-cruises-de          True
# 9215490      princess-cruises-us          True
# 9364722               tallink-ee         False
# 9813072     hurtigruten-group-no         False
# ...                          ...           ...
# 7361324            moby-lines-it         False
# 9479864         costa-cruises-it          True
# 9767091  carnival-cruise-line-us          True
# 9221346         naviera-armas-es         False
# 9501590            molslinjen-dk         False
#
#                                                      photo  \
# imo
# 9332559  /img/300px-Stena_Horizon_approaching_Rosslare_...
# 9783576                     /img/mein-schiff-2-9783576.jpg
# 9215490                /img/caribbean-princess-9215490.jpg
# 9364722                /img/300px-190407_Star_Helsinki.jpg
# 9813072                    /img/roald-amundsen-9813072.jpg
# ...                                                    ...
# 7361324  /img/300px-Princess_of_Scandinavia_Gothenburg.jpg
# 9479864      /img/300px-Costa_Fascinosa_close_to_Corfu.jpg
# 9767091                  /img/carnival-horizon-9767091.jpg
# 9221346  /img/300px-Highspeed_6_-_HSW_-_Heraklion_-_Por...
# 9501590                         /img/express-1-9501590.jpg
#
#                                             wikipedia_url  unknown_routes  \
# imo
# 9332559    https://en.wikipedia.org/wiki/MS_Stena_Horizon           False
# 9783576                                               NaN           False
# 9215490  https://fr.wikipedia.org/wiki/Caribbean_Princess           False
# 9364722             https://en.wikipedia.org/wiki/MS_Star           False
# 9813072   https://en.wikipedia.org/wiki/MS_Roald_Amundsen           False
# ...                                                   ...             ...
# 7361324        https://en.wikipedia.org/wiki/MS_Moby_Otta           False
# 9479864     https://en.wikipedia.org/wiki/Costa_Fascinosa           False
# 9767091    https://en.wikipedia.org/wiki/Carnival_Horizon           False
# 9221346  https://en.wikipedia.org/wiki/HSC_Volcan_de_Teno           False
# 9501590       https://en.wikipedia.org/wiki/HSC_Express_1           False
#
#          capacity_pax
# imo
# 9332559           NaN
# 9783576           NaN
# 9215490           NaN
# 9364722        1900.0
# 9813072           NaN
# ...               ...
# 7361324           NaN
# 9479864        3800.0
# 9767091           NaN
# 9221346           NaN
# 9501590           NaN
#
# [543 rows x 8 columns]

# %%
db_con = sqlite3.connect(os.path.join(REPO_ROOT, "dbs/www.db"))

df_ships.to_sql("ships", db_con, if_exists="replace")
df_routes.to_sql("routes", db_con, if_exists="replace")
df_companies.to_sql("companies", db_con, if_exists="replace")
df_ships_routes.to_sql("ships_routes", db_con, if_exists="replace")
df_cities.to_sql("cities", db_con, if_exists="replace")
# Out:
# 187
